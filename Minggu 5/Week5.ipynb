# %% [markdown]
# <a href="https://colab.research.google.com/github/kausar-vento/PCVK_Genap_2023/blob/main/Minggu%205/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive

# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Nomor 1

# %%
print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
  gamma = float(input('Masukkan nilai Gamma: '))
except ValueError:
  print('Error, not a number')
original = cv.imread('/content/drive/MyDrive/PCVK/Images/female.tiff')
rumus_gamma = 255 * (original/255) ** (1/gamma)
rumus_gamma = np.uint8(rumus_gamma)
final_frame = cv.hconcat((original, rumus_gamma))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FA0441B1610>

# %% [markdown]
# ## Nomor 2

# %%
img_path = '/content/drive/MyDrive/PCVK/Images/female.tiff'
original = cv.imread(img_path, cv.IMREAD_GRAYSCALE)
bit_depth = 2
level = 255 / (pow(2, bit_depth) - 1)
depth_image = np.zeros(original.shape, original.dtype)
depth_image = np.round(original / level) * level
result = np.concatenate([original, depth_image], axis=1)
fig, ax = plt.subplots(figsize=(12, 6))
ax.imshow(result, cmap='gray')
plt.show()

# %% [markdown]
# ## Nomor 3 AVG = 5

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/Images/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/Images/noises/*.jpg'):
  n = cv.imread(img)
  cv_img.append(n)

dst = cv_img[0]
noise_number = 4 # nomor (array) gambar pada folder noises
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)
def PSNR (img1, img2):
  mse = np.mean((img1 - img2) ** 2)
  if (mse == 0) :
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr


compres = dst
psnr = PSNR(original, compres)

print('Nilai PSNR = ', psnr)
final_frame = cv.hconcat((original, dst))
cv2_imshow(final_frame)
# Out:
# Nilai PSNR =  27.53743916156828
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FA030453220>

# %% [markdown]
# ## Nomor 3 AVG = 30

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/Images/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/Images/noises/*.jpg'):
  n = cv.imread(img)
  cv_img.append(n)

dst = cv_img[0]
noise_number = 29 # nomor (array) gambar pada folder noises
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)
def PSNR (img1, img2):
  mse = np.mean((img1 - img2) ** 2)
  if (mse == 0) :
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

compres = dst
psnr = PSNR(original, compres)

print('Nilai PSNR = ', psnr)
final_frame = cv.hconcat((original, dst))
cv2_imshow(final_frame)
# Out:
# Nilai PSNR =  27.52086505776816
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FA032EEAD60>

# %% [markdown]
# ## Nomor 3 AVG = 60

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/Images/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/Images/noises/*.jpg'):
  n = cv.imread(img)
  cv_img.append(n)

dst = cv_img[0]
noise_number = 59 # nomor (array) gambar pada folder noises
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)
def PSNR (img1, img2):
  mse = np.mean((img1 - img2) ** 2)
  if (mse == 0) :
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

compres = dst
psnr = PSNR(original, compres)

print('Nilai PSNR = ', psnr)
final_frame = cv.hconcat((original, dst))
cv2_imshow(final_frame)
# Out:
# Nilai PSNR =  27.485757638732142
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FA0303C1FA0>

# %% [markdown]
# ## Nomor 3 AVG = 80

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/Images/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/Images/noises/*.jpg'):
  n = cv.imread(img)
  cv_img.append(n)

dst = cv_img[0]
noise_number = 79 # nomor (array) gambar pada folder noises
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)
def PSNR (img1, img2):
  mse = np.mean((img1 - img2) ** 2)
  if (mse == 0) :
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

compres = dst
psnr = PSNR(original, compres)

print('Nilai PSNR = ', psnr)
final_frame = cv.hconcat((original, dst))
cv2_imshow(final_frame)
# Out:
# Nilai PSNR =  27.507500880013627
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FA030532490>

# %% [markdown]
# ## Nomor 3 AVG = 100

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/Images/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/Images/noises/*.jpg'):
  n = cv.imread(img)
  cv_img.append(n)

dst = cv_img[0]
noise_number = 99 # nomor (array) gambar pada folder noises
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)
def PSNR (img1, img2):
  mse = np.mean((img1 - img2) ** 2)
  if (mse == 0) :
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

compres = dst
psnr = PSNR(original, compres)

print('Nilai PSNR = ', psnr)
final_frame = cv.hconcat((original, dst))
cv2_imshow(final_frame)
# Out:
# Nilai PSNR =  27.518003238591472
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FA0303CFD30>

# %%
# Load the image
original = cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

# Create a mask
mask = np.zeros(original.shape[:2], dtype=np.uint8)


# Draw two circles on the mask
circle1 = (75, 50)
radius1 = 45
cv.circle(mask, circle1, radius1, (255, 255, 255), -1)

circle2 = (185, 50)
radius2 = 45
cv.circle(mask, circle2, radius2, (255, 255, 255), -1)

white = np.full(original.shape, 255, dtype=np.uint8)
# Apply the mask to the image
masked_img = cv.bitwise_or(original, original, mask=mask)

# Display the result
final_frame = cv.hconcat((original, masked_img))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FA03038E430>

# %%
# Load the image
original = cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

# Create a mask
mask = np.zeros(original.shape[:2], dtype=np.uint8)


# Draw two circles on the mask
circle1 = (75, 50)
radius1 = 45
cv.circle(mask, circle1, radius1, (255, 255, 255), -1)

circle2 = (185, 50)
radius2 = 45
cv.circle(mask, circle2, radius2, (255, 255, 255), -1)

white = np.full(original.shape, 255, dtype=np.uint8)
# Apply the mask to the image
masked_img = cv.bitwise_not(original, original, mask=mask)

# Display the result
final_frame = cv.hconcat((original, masked_img))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FA030456730>

# %%
# Load the image
original = cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

# Create a mask
mask = np.zeros(original.shape[:2], dtype=np.uint8)


# Draw two circles on the mask
circle1 = (75, 50)
radius1 = 45
cv.circle(mask, circle1, radius1, (255, 255, 255), -1)

circle2 = (185, 50)
radius2 = 45
cv.circle(mask, circle2, radius2, (255, 255, 255), -1)

white = np.full(original.shape, 255, dtype=np.uint8)
# Apply the mask to the image
masked_img = cv.bitwise_and(original, original, mask=mask)

# Display the result
final_frame = cv.hconcat((original, masked_img))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FA0303A68B0>

# %%
# Load the image
original = cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

# Create a mask
mask = np.zeros(original.shape[:2], dtype=np.uint8)


# Draw two circles on the mask
circle1 = (75, 50)
radius1 = 45
cv.circle(mask, circle1, radius1, (255, 255, 255), -1)

circle2 = (185, 50)
radius2 = 45
cv.circle(mask, circle2, radius2, (255, 255, 255), -1)

white = np.full(original.shape, 255, dtype=np.uint8)
# Apply the mask to the image
masked_img = cv.bitwise_xor(original, original, mask=mask)

# Display the result
final_frame = cv.hconcat((original, masked_img))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FA04D972070>

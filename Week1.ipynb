# %% [markdown]
# <a href="https://colab.research.google.com/github/kausar-vento/PCVK_Genap_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# menyimpan list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]

# baca dan tampilkan image
# proses loop pada tiap url image, dan beberapa image akan disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F7F3BAEDD90>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7F47E59A30>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7F44143EB0>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi Image = Tinggi * Lebar = ", tinggi, " X ", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi Image = Tinggi * Lebar =  286  X  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F7F3BAF4520>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
image_3[int((tinggi)/2),:] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7F440897C0>

# %% [markdown]
# ## PERTANYAAN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## JAWABAN

# %% [markdown]
# 1.   Google Open Source, dan bisa digunakan dengan gratis, google collab memiliki banyak libary yang tersedial, dan google collab ringan karena fasilitas ram dan disk disediakan oleh pihak google tersebut
#
# 2.   A. Numppy Untuk Libary Manipulasi Array
#
#      B. Pandas Untuk Libary Manipulasi Data Dan Data Analisis
#
#      C. CV2 Untuk menyederhanakan programing terkait citra digital
#
#      D. Skimage Untuk Support Proses Gambar
#
#      E. Matplotlib Menyediakan toolkit interface
#
#      Tidak Semua Libary Digunakan Dalam Pratikum Ini, Contohnya Matplotlib, Numppy, Pandas, Dan Pada Libary Skimage Transform tidak digunakan
#
# 3. Kegunaan kode program tersebut adalah mengecilkan ukuran asli dari gambar tersebut, jika tidak digunakan maka gambar yang ditampilkan akan berukuran besar
#
# 4. untuk membuat garis putih
#
# 5. Resolusi adalah jumlah pixel atau picture element yang tersusun dalam sebuah gambar digital. Resolusi adalah kerapatan pixel pada sebuah gambar dan tersusun dari pixel (kotak kecil). Resolusi dapat diukur sesuai kerapatan pixel dalam 1 inch, jadi semakin besar resolusinya maka gambar akan terlihat detail. jika semakin resolusi besar, maka gambar akan lebih bagus dan sebaliknya

# %% [markdown]
# ### JAWABAN TUGAS NOMOR 2

# %%
image_2_n = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3_n = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for x in range (tinggi):
  image_3_n[x,190] = [255,255,255]
final_frame_n = cv.hconcat((image_2_n, image_3_n))
cv2_imshow(final_frame_n)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7F3B82F280>

# %%
image_2_m = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3_m = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for x in range (tinggi):
  image_3_m[x,x] = [255,255,255]
# cv.line(image_3_m, (lebar, tinggi), (0, 0), (255,255,255), 1)
# cv.line(image_3_m, (0, tinggi), (lebar, 0), (255,255,255), 1)
final_frame_m = cv.hconcat((image_2_m, image_3_m))
cv2_imshow(final_frame_m)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7F3BAF46D0>

# %% [markdown]
# ### JAWABAN TUGAS NOMOR 3

# %%
image_2_p = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3_p = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
cv.line(image_3_p, (100, int((tinggi/2))), (250, int((tinggi/2))), (255,255,255), 1)
final_frame_m = cv.hconcat((image_2_p, image_3_p))
cv2_imshow(final_frame_m)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7F3BAF4BB0>

# %% [markdown]
# ### JAWABAN TUGAS NOMOR 4

# %%
image_2_p = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3_p = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
cv.rectangle(image_3_p,(100,100),(250,250),(255,255,255),-1)
final_frame_m = cv.hconcat((image_2_p, image_3_p))
cv2_imshow(final_frame_m)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7F3BAF4880>

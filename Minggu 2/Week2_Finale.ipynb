# %% [markdown]
# <a href="https://colab.research.google.com/github/kausar-vento/PCVK_Genap_2023/blob/main/Minggu%202/Week2_Finale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/kitten01.jpg')
plt.imshow(img)

# %% [markdown]
# OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan
# citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/mandrill2.tiff', img5)

#tampilan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv.rectangle(black_img, pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Pertanyaan
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. perbedaan utamanya adalah jika gambar yang ditampilkan dengan matplotlib dapat dimodifikasi dan bisa menampilkan kordinat, sedangkan jika tidak maka gambar tidak memunculkan kordninat
# 2.   Perbedaanya adalah jika tipe int32, maka warna hitam akan semakin tebal, dan jika tipe data int 16 maka gambar warna hitam tidak terlalu tebal
# 3.  menambahkan fitur cv2_imshow kedalam libary google collab, kegunaanya adalah untuk menampilkan gambar dalam notebook Google Colab
# 4. skimage merupakan libary dari python kegunanaya adalah untuk pengeolahan gambar sedangkan "io" merupakan modul dari skimage kegunaanya adalah untuk membaca dan menulis gambar dalam berbagai format

# %% [markdown]
# # TUGAS
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 1

# %%
img_tugas_1 = img

img_tugas_1_color = cv.cvtColor(img_tugas_1, cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
ax.imshow(img_tugas_1_color)

# %% [markdown]
# ### JIKA MENGGUNAKAN FIG SIZE, MAKA UKURAN PIXEL TIDAK AKAN BERUBAH, HANYA MERUBAH UKURAN GAMBARNYA SAJA

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 2

# %%
# Menampilkan Red-Blue
img_tugas_2_rb = img
img_tugas_2_color_rb = cv.cvtColor(img_tugas_2_rb, cv.COLOR_BGR2RGB)
img_tugas_2_color_rb[:, :, 1] = 0

# Menampilkan Green-Blue
img_tugas_2_gb = img
img_tugas_2_color_gb = cv.cvtColor(img_tugas_2_gb, cv.COLOR_BGR2RGB)
img_tugas_2_color_gb[:, :, 0] = 0

tampilBerdua = cv.hconcat((img_tugas_2_color_rb, img_tugas_2_color_gb))
plt.imshow(tampilBerdua)

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 3

# %%
img_tugas_3 = img
img_tugas_3 = cv.cvtColor(img_tugas_3, cv.COLOR_BGR2RGB)
potongImage = img_tugas_3[20:115, 25:120]
plt.imshow(potongImage)

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 4

# %%
img_tugas_4 = img
img_tugas_4 = cv.cvtColor(img_tugas_4, cv.COLOR_BGR2RGB)
potongImage_4 = img_tugas_4[5:30, :]
potongImage_4[:, :, 2] = 0
potongImage_4[:, :, 1] = 0
plt.imshow(potongImage_4)

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 5

# %%
import random

img_tugas_5 = img
img_tugas_5_color = cv.cvtColor(img_tugas_5, cv.COLOR_BGR2RGB)
for x in range(5):
  cv.rectangle(img_tugas_5_color,pt1=(random.randint(0,500),random.randint(0,500)),
               pt2=(random.randint(0,500),random.randint(0,500)),color=(random.randint(0,255),
               random.randint(0,255),random.randint(0,255)),thickness=15)
plt.imshow(img_tugas_5_color)

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 6

# %%
img_tugas_6 = img
img_tugas_6_color = cv.flip(cv.cvtColor(img_tugas_6, cv.COLOR_BGR2RGB), 0) # konversi channel BGR -> RGB
plt.imshow(img_tugas_6_color)

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 7

# %%
img2 = cv.imread('/content/drive/MyDrive/PCVK/aktivitas2.jpg')
plt.imshow(img2)
img_tugas_07 = img2
img_tugas_07_color = cv.resize(cv.cvtColor(img_tugas_07, cv.COLOR_BGR2RGB), (2400, 1500)) # konversi channel BGR -> RGB
cv.rectangle(img_tugas_07_color,pt1=(1550,200),pt2=(1750,500),color=(0,0,255),thickness=15)
cv.circle(img_tugas_07_color,center=(1650,340),radius=150,color=(255,0,0),thickness=8)
plt.imshow(img_tugas_07_color)

# %% [markdown]
# ## JAWABAN TUGAS NOMOR 8 & 9

# %%
img_nomor_8_9 = cv.imread('/content/drive/MyDrive/PCVK/peppers.jpg')
img_nomor_8_9_color = cv.cvtColor(img_nomor_8_9, cv.COLOR_BGR2RGB)
cv.rectangle(img_nomor_8_9_color,pt1=(0,450),pt2=(100,500),color=(0,0,255),thickness=10)
cv.putText(img_nomor_8_9_color, text='Al Kausar',org=(10,100),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img_nomor_8_9_color)
